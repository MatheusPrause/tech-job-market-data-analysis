# %%
"""
Project: Tech Job Market Data Analysis (Brazil)

This notebook defines the analytical context of the project, including
the problem statement, objectives, and key questions that will guide
all future analyses.

No data manipulation is performed at this stage.
"""
# Out:
# '\nProject: Tech Job Market Data Analysis (Brazil)\n\nThis notebook defines the analytical context of the project, including\nthe problem statement, objectives, and key questions that will guide\nall future analyses.\n\nNo data manipulation is performed at this stage.\n'

# %%
# Problem Statement

"""
The Brazilian technology job market is highly dynamic, with constant changes
in salary levels, demanded skills, seniority requirements, and geographic
distribution of opportunities.

Professionals, companies, and students often lack structured data-driven
insights to support career planning, hiring decisions, and market analysis.
"""
# Out:
# '\nThe Brazilian technology job market is highly dynamic, with constant changes\nin salary levels, demanded skills, seniority requirements, and geographic\ndistribution of opportunities.\n\nProfessionals, companies, and students often lack structured data-driven\ninsights to support career planning, hiring decisions, and market analysis.\n'

# %%
# Analysis Objective

"""
The objective of this project is to analyze real-world data related to the
Brazilian technology job market in order to identify trends, patterns, and
insights regarding salaries, skills demand, seniority levels, regional
differences, and remote work impact.
"""
# Out:
# '\nThe objective of this project is to analyze real-world data related to the\nBrazilian technology job market in order to identify trends, patterns, and\ninsights regarding salaries, skills demand, seniority levels, regional\ndifferences, and remote work impact.\n'

# %%
# Key Analytical Questions

questions = [
    "Which technology roles have the highest average salaries in Brazil?",
    "How do salaries vary by seniority level?",
    "What technologies and skills are most in demand?",
    "Are there significant salary differences between regions?",
    "How does remote work influence compensation levels?"
]

questions
# Out:
# ['Which technology roles have the highest average salaries in Brazil?',
#  'How do salaries vary by seniority level?',
#  'What technologies and skills are most in demand?',
#  'Are there significant salary differences between regions?',
#  'How does remote work influence compensation levels?']

# %%
# Success Criteria

"""
This analysis will be considered successful if it provides:
- Clear and reproducible insights based on data
- Well-documented analytical steps
- Visualizations that support decision-making
- Business-oriented interpretations of results
"""
# Out:
# '\nThis analysis will be considered successful if it provides:\n- Clear and reproducible insights based on data\n- Well-documented analytical steps\n- Visualizations that support decision-making\n- Business-oriented interpretations of results\n'
