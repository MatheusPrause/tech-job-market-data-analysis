# %% [markdown]
# # Notebook 01 – Environment Check
# ## Project: Tech Job Market Data Analysis
# ### Author: Matheus Prause
# ### Date: 2026
# ## Objective: Validate environment, libraries, and project structure.
