# %%
# Data Analysis Fundamentals
"""
This notebook applies the core concepts learned in the course
"Trabalhando com dados: fundamentos da análise de dados".

The goal is to demonstrate the analytical thinking process
behind data analysis before diving into complex models.
"""
# Out:
# '\nThis notebook applies the core concepts learned in the course\n"Trabalhando com dados: fundamentos da análise de dados".\n\nThe goal is to demonstrate the analytical thinking process\nbehind data analysis before diving into complex models.\n'

# %%
## What is Data Analysis?
"""
Data analysis is the process of collecting, cleaning, exploring,
and interpreting data in order to extract insights and support
decision-making.

It transforms raw data into meaningful information.
"""
# Out:
# '\nData analysis is the process of collecting, cleaning, exploring,\nand interpreting data in order to extract insights and support\ndecision-making.\n\nIt transforms raw data into meaningful information.\n'

# %%
## Types of Data
"""
- **Qualitative (Categorical):** categories or labels
- **Quantitative (Numerical):** measurable numeric values
  - Discrete
  - Continuous
"""
# Out:
# '\n- **Qualitative (Categorical):** categories or labels\n- **Quantitative (Numerical):** measurable numeric values\n  - Discrete\n  - Continuous\n'

# %%
## Data Analysis Process
"""
1. Problem definition
2. Data collection
3. Data cleaning
4. Exploratory Data Analysis (EDA)
5. Insights and conclusions
"""
# Out:
# '\n1. Problem definition\n2. Data collection\n3. Data cleaning\n4. Exploratory Data Analysis (EDA)\n5. Insights and conclusions\n'

# %%
# Simple example to represent structured data
sample_data = {
    "role": ["Data Analyst", "Data Scientist", "ML Engineer"],
    "avg_salary_usd": [70000, 95000, 120000]
}

sample_data
# Out:
# {'role': ['Data Analyst', 'Data Scientist', 'ML Engineer'],
#  'avg_salary_usd': [70000, 95000, 120000]}
